# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %% [markdown]
# import random
#
# dado_1 = random.randint(1, 6)
# dado_2 = random.randint(1, 6)
# total_dados = dado_1 + dado_2
# iterar = 1000
#
#
# #def probabilidades (iterar): # como se cuando ponerle parametros si puedo dejar los parentesis vacios o cuales son los parametros
#     contador = 0
#     for total_dados in range (iterar): # creo un loop para que entre en "total_dados" 1000 veces
#        if total_dados > 7 or total_dados % 2 == 0: #solo le pido que me traiga mayores de 7 o pares
#               contador +=1 #le pido que vaya guarando los resultados
#               porcentaje = contador / iterar # le pido que guarde en porcentaje lo que guarda en contador y lo divida por 1000
#     return porcentaje
#
# resultado = probabilidades(iterar) #llamo a la funcion "probabildades" cuyo parametro es 1000 y lo guardo en "resultado"
# print(resultado)

# %%
import random

def probabilidades (simulaciones = 1000): 
    contador = 0
    for x in range(simulaciones):
        dado_1 = random.randint(1,6)
        dado_2 = random.randint(1,6)
        dado_suma = dado_1 + dado_2
        if dado_suma > 7 or dado_suma % 2 == 0:
           contador +=1
    return contador / simulaciones

probabilidades(10000)
print(f"La probabilidad que mayor que 7 y divisible por dos es:, {probabilidades(10000)}")
# Out:
# La probabilidad que mayor que 7 y divisible por dos es:, 0.6734

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
ball_box = {} # esto es un dicicionario vacia? aqui se va a guardar bolas de cierto color en cierta posicion de la lista???

for i in range(60): #voy a iterar 60 veces
    if i < 10: #le pregunto a i cuanto vale y si me dice que vale 1 a 10 se trata de bolas blancas
        ball_box[i] = "White" # que quiere decir esa i entre corchetes a que se refiere??? 
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

print(ball_box)
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green'}

# %%
import numpy as np

def tirar_bola(simulaciones = 1000):
    contador_1 = 0
    contador_2 = 0

    for i in range (simulaciones):
        color = []
        
        for x in range(5):
            color.append(ball_box)

    bolas_blancas = sum(color == "White")
    bolas_rojas = sum(color == "Red")
    bolas_verdes = sum(color == "Green")

  

    if (bolas_blancas == 3) and (bolas_rojas == 2):
        contador_1 += 1
    if (bolas_blancas == 5) or (bolas_rojas == 5) or (bolas_verdes == 5):
        contador_2 += 1
               

        

    return contador_1 / simulaciones, contador_2 / simulaciones

posibilidades = tirar_bola(1000)



print(f"La probabilidad de que salgan dos bolas rojas y tres blancas es  {posibilidades[0]}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 29
#      22         contador_2 += 1
#      27     return contador_1 / simulaciones, contador_2 / simulaciones
# ---> 29 posibilidades = tirar_bola(1000)
#      33 print(f"La probabilidad de que salgan dos bolas rojas y tres blancas es  {posibilidades[0]}")
#
# Cell In[40], line 13, in tirar_bola(simulaciones)
#      10     for x in range(5):
#      11         color.append(ball_box)
# ---> 13 bolas_blancas = sum(color == "White")
#      14 bolas_rojas = sum(color == "Red")
#      15 bolas_verdes = sum(color == "Green")
#
# TypeError: 'bool' object is not iterable
